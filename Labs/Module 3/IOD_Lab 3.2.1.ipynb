# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 3.2.1
# # *Querying the International Space Station*

# %% [markdown]
# ## The OpenNotify API

# %% [markdown]
# The OpenNotify API exposes a few attributes of the International Space Station (ISS) via a simple, authentication-free interface. The simplicity of this API precludes any need for a dedicated Python library. However, as with many APIs, it accepts requests according to HTTP standards and returns responses in JSON format, so the Python libraries request and json will make managing the I/O simpler still.

# %%
import requests
import json
from datetime import datetime, date, time

# %% [markdown]
# This request fetches the latest position of the international space station:

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")

# %% [markdown]
# Print the status code and text of the response:

# %%
#ANSWER
response.status_code
# Out:
# 200

# %%
#ANSWER
response.text
# Out:
# '{"message": "success", "timestamp": 1695432272, "iss_position": {"latitude": "-13.1636", "longitude": "170.2862"}}'

# %% [markdown]
# We can use another API to request the current position of the ISS and the next few times at which it will be over a certain location. The latitude and longitude of Sydney are (-33.87, 151.21).

# %%
response = requests.get("https://api.g7vrd.co.uk/v1/satellite-passes/25544/-33.87/151.21.json?minelevation=0&hours=24")

# %% [markdown]
# Print the response header:

# %%
#ANSWER
response.headers
# Out:
# {'Date': 'Sat, 23 Sep 2023 01:24:41 GMT', 'Server': 'Apache', 'Vary': 'Origin,Access-Control-Request-Method,Access-Control-Request-Headers', 'Access-Control-Allow-Origin': '*', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 'no-cache, no-store, max-age=0, must-revalidate', 'Pragma': 'no-cache', 'Expires': '0', 'X-Frame-Options': 'DENY', 'Content-Type': 'application/json', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked'}

# %% [markdown]
# Print the content of the response (the data that the server returned):

# %%
#ANSWER
response.content
# Out:
# b'{"api_status":"ALPHA","request_timestamp":"2023-09-23T01:24:41.965319050Z","norad_id":25544,"satellite_name":"ISS","tle_last_retrieved":"2023-09-22T14:06:25.096380744Z","lat":-33.87,"lon":151.21,"hours":24,"min_elevation":0,"query_ms":15,"passes":[{"start":"2023-09-23T02:49:56.951Z","tca":"2023-09-23T02:53:26.951Z","end":"2023-09-23T02:57:11.951Z","aos_azimuth":261,"los_azimuth":345,"max_elevation":6.0},{"start":"2023-09-23T16:15:46.951Z","tca":"2023-09-23T16:20:46.951Z","end":"2023-09-23T16:25:51.951Z","aos_azimuth":345,"los_azimuth":118,"max_elevation":20.0},{"start":"2023-09-23T17:52:01.951Z","tca":"2023-09-23T17:57:31.951Z","end":"2023-09-23T18:02:46.951Z","aos_azimuth":292,"los_azimuth":141,"max_elevation":31.0},{"start":"2023-09-23T19:31:06.951Z","tca":"2023-09-23T19:35:06.951Z","end":"2023-09-23T19:39:01.951Z","aos_azimuth":244,"los_azimuth":152,"max_elevation":7.0},{"start":"2023-09-23T21:10:36.951Z","tca":"2023-09-23T21:13:36.951Z","end":"2023-09-23T21:16:26.951Z","aos_azimuth":209,"los_azimuth":145,"max_elevation":3.0},{"start":"2023-09-23T22:47:36.951Z","tca":"2023-09-23T22:51:36.951Z","end":"2023-09-23T22:56:06.951Z","aos_azimuth":207,"los_azimuth":106,"max_elevation":9.0},{"start":"2023-09-24T00:23:51.951Z","tca":"2023-09-24T00:29:21.951Z","end":"2023-09-24T00:34:46.951Z","aos_azimuth":221,"los_azimuth":57,"max_elevation":48.0},{"start":"2023-09-24T02:01:11.951Z","tca":"2023-09-24T02:05:41.951Z","end":"2023-09-24T02:10:21.951Z","aos_azimuth":249,"los_azimuth":3,"max_elevation":13.0}]}'

# %% [markdown]
# Note that this is a Python byte string:

# %%
print(type(response.content))
# Out:
# <class 'bytes'>

# %% [markdown]
# Print just the "content-type" value from the header:

# %%
#ANSWER
type(response.headers["content-type"])
# Out:
# str

# %% [markdown]
# JSON was designed to be easy for computers to read, not for people. The `requests` library can decode the JSON byte string:

# %%
overheads = response.json()
print(overheads)
# Out:
# {'api_status': 'ALPHA', 'request_timestamp': '2023-09-23T03:45:23.506279298Z', 'norad_id': 25544, 'satellite_name': 'ISS', 'tle_last_retrieved': '2023-09-22T14:06:25.096380744Z', 'lat': -33.87, 'lon': 151.21, 'hours': 24, 'min_elevation': 0, 'query_ms': 21, 'passes': [{'start': '2023-09-23T16:15:43.485Z', 'tca': '2023-09-23T16:20:43.485Z', 'end': '2023-09-23T16:25:48.485Z', 'aos_azimuth': 344, 'los_azimuth': 118, 'max_elevation': 20.0}, {'start': '2023-09-23T17:52:03.485Z', 'tca': '2023-09-23T17:57:33.485Z', 'end': '2023-09-23T18:02:48.485Z', 'aos_azimuth': 292, 'los_azimuth': 141, 'max_elevation': 31.0}, {'start': '2023-09-23T19:31:08.485Z', 'tca': '2023-09-23T19:35:08.485Z', 'end': '2023-09-23T19:38:58.485Z', 'aos_azimuth': 244, 'los_azimuth': 153, 'max_elevation': 7.0}, {'start': '2023-09-23T21:10:38.485Z', 'tca': '2023-09-23T21:13:38.485Z', 'end': '2023-09-23T21:16:23.485Z', 'aos_azimuth': 209, 'los_azimuth': 146, 'max_elevation': 3.0}, {'start': '2023-09-23T22:47:38.485Z', 'tca': '2023-09-23T22:51:38.485Z', 'end': '2023-09-23T22:56:08.485Z', 'aos_azimuth': 207, 'los_azimuth': 106, 'max_elevation': 9.0}, {'start': '2023-09-24T00:23:53.485Z', 'tca': '2023-09-24T00:29:23.485Z', 'end': '2023-09-24T00:34:48.485Z', 'aos_azimuth': 221, 'los_azimuth': 57, 'max_elevation': 48.0}, {'start': '2023-09-24T02:01:13.485Z', 'tca': '2023-09-24T02:05:43.485Z', 'end': '2023-09-24T02:10:23.485Z', 'aos_azimuth': 249, 'los_azimuth': 3, 'max_elevation': 13.0}, {'start': '2023-09-24T15:28:33.485Z', 'tca': '2023-09-24T15:33:03.485Z', 'end': '2023-09-24T15:37:23.485Z', 'aos_azimuth': 0, 'los_azimuth': 108, 'max_elevation': 11.0}]}

# %% [markdown]
# What kind of object did this give us?

# %%
#ANSWER:
type(overheads)
# Out:
# dict

# %% [markdown]
# Python dicts are easier to work with, but the data we want is still buried in that data structure, so we have to dig it out. First, extract the `response` value to a separate list:

# %%
#ANSWER:
passes = list(overheads['passes'])
passes
# Out:
# [{'start': '2023-09-23T16:15:43.485Z',
#   'tca': '2023-09-23T16:20:43.485Z',
#   'end': '2023-09-23T16:25:48.485Z',
#   'aos_azimuth': 344,
#   'los_azimuth': 118,
#   'max_elevation': 20.0},
#  {'start': '2023-09-23T17:52:03.485Z',
#   'tca': '2023-09-23T17:57:33.485Z',
#   'end': '2023-09-23T18:02:48.485Z',
#   'aos_azimuth': 292,
#   'los_azimuth': 141,
#   'max_elevation': 31.0},
#  {'start': '2023-09-23T19:31:08.485Z',
#   'tca': '2023-09-23T19:35:08.485Z',
#   'end': '2023-09-23T19:38:58.485Z',
#   'aos_azimuth': 244,
#   'los_azimuth': 153,
#   'max_elevation': 7.0},
#  {'start': '2023-09-23T21:10:38.485Z',
#   'tca': '2023-09-23T21:13:38.485Z',
#   'end': '2023-09-23T21:16:23.485Z',
#   'aos_azimuth': 209,
#   'los_azimuth': 146,
#   'max_elevation': 3.0},
#  {'start': '2023-09-23T22:47:38.485Z',
#   'tca': '2023-09-23T22:51:38.485Z',
#   'end': '2023-09-23T22:56:08.485Z',
#   'aos_azimuth': 207,
#   'los_azimuth': 106,
#   'max_elevation': 9.0},
#  {'start': '2023-09-24T00:23:53.485Z',
#   'tca': '2023-09-24T00:29:23.485Z',
#   'end': '2023-09-24T00:34:48.485Z',
#   'aos_azimuth': 221,
#   'los_azimuth': 57,
#   'max_elevation': 48.0},
#  {'start': '2023-09-24T02:01:13.485Z',
#   'tca': '2023-09-24T02:05:43.485Z',
#   'end': '2023-09-24T02:10:23.485Z',
#   'aos_azimuth': 249,
#   'los_azimuth': 3,
#   'max_elevation': 13.0},
#  {'start': '2023-09-24T15:28:33.485Z',
#   'tca': '2023-09-24T15:33:03.485Z',
#   'end': '2023-09-24T15:37:23.485Z',
#   'aos_azimuth': 0,
#   'los_azimuth': 108,
#   'max_elevation': 11.0}]

# %% [markdown]
# Now extract the `start` strings into an array called `srisetimes`:

# %%
#ANSWER:
srisetimes = [item['start'] for item in passes]
srisetimes
# Out:
# ['2023-09-23T16:15:43.485Z',
#  '2023-09-23T17:52:03.485Z',
#  '2023-09-23T19:31:08.485Z',
#  '2023-09-23T21:10:38.485Z',
#  '2023-09-23T22:47:38.485Z',
#  '2023-09-24T00:23:53.485Z',
#  '2023-09-24T02:01:13.485Z',
#  '2023-09-24T15:28:33.485Z']

# %% [markdown]
# These are strings. We convert these to an array of Python `datetime` values called `risetimes`:

# %%
risetimes = [datetime.strptime(xpass['start'], "%Y-%m-%dT%H:%M:%S.%fZ") for xpass in passes]
for risetime in risetimes:
    print(risetime)
# Out:
# 2023-09-23 16:15:43.485000
# 2023-09-23 17:52:03.485000
# 2023-09-23 19:31:08.485000
# 2023-09-23 21:10:38.485000
# 2023-09-23 22:47:38.485000
# 2023-09-24 00:23:53.485000
# 2023-09-24 02:01:13.485000
# 2023-09-24 15:28:33.485000

# %% [markdown]
# Finally, use `risetime.strftime` to print these in a format that people understand:
#
# ```
# e.g.
# 18/10/22 07:05
# 18/10/22 08:41
# 18/10/22 10:20
# 18/10/22 12:00
# 18/10/22 01:37
# 18/10/22 03:13
# ```

# %%
#ANSWER:
for risetime in risetimes:
    formatted_date = risetime.strftime('%Y-%m-%d %H:%M')
    print(formatted_date)
# Out:
# 2023-09-23 16:15
# 2023-09-23 17:52
# 2023-09-23 19:31
# 2023-09-23 21:10
# 2023-09-23 22:47
# 2023-09-24 00:23
# 2023-09-24 02:01
# 2023-09-24 15:28

# %% [markdown]
# Finally, here is an endpoint that tells us who is on board:

# %%
response = requests.get("http://api.open-notify.org/astros.json")

# %% [markdown]
# Referring to the methods used above, extract the number of astronauts and their names:

# %%
#ANSWER:

# %% [markdown]
# ## HOMEWORK

# %% [markdown]
# 1. Write a simple handler for the response status code (refer to lab resources slide for HTTP response codes). As this Jupyter Notebook is an interactive device, the handler does not need to manage subsequent code execution (i.e. by branching or aborting execution), although it should return something that could be used to do so if deployed in a Python program.

# %%
#ANSWER:
def handleResponse(response, verbose = False):
    '''
    Returns Boolean Value, Status Code, 
    '''
  # if Status Code is 200 return false, and status code
  # Otherwise Return True and Status Code

# %% [markdown]
# 2. Test your response handler on some correct and incorrect API calls.

# %%
response = requests.get("http://api.open-notify.org/astros.json")
if handleResponse(response)[0]:
    print('API call failed. Resolve issue before continuing!')
    
response = requests.get("http://api.open-notify.org/iss-now.json")
handleResponse(response, True)[0]

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
